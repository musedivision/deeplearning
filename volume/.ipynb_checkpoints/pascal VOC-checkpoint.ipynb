# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.conv_learner import *
from fastai.dataset import *

from pathlib import Path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

# %%
PATH = Path('data/pascal/')
list(PATH.iterdir())
# Out:
# [PosixPath('data/pascal/VOCdevkit'),
#  PosixPath('data/pascal/pascal_train2012.json'),
#  PosixPath('data/pascal/pascal_val2012.json'),
#  PosixPath('data/pascal/pascal_val2007.json'),
#  PosixPath('data/pascal/pascal_train2007.json'),
#  PosixPath('data/pascal/pascal_test2007.json')]

# %%
train_keys = json.load((PATH/'pascal_train2007.json').open())
train_keys.keys()
# Out:
# dict_keys(['images', 'type', 'annotations', 'categories'])

# %%
IMAGES, ANNOTATIONS, CATEGORIES = ['images', 'annotations', 'categories']
train_keys[IMAGES][:5]
# Out:
# [{'file_name': '000012.jpg', 'height': 333, 'id': 12, 'width': 500},
#  {'file_name': '000017.jpg', 'height': 364, 'id': 17, 'width': 480},
#  {'file_name': '000023.jpg', 'height': 500, 'id': 23, 'width': 334},
#  {'file_name': '000026.jpg', 'height': 333, 'id': 26, 'width': 500},
#  {'file_name': '000032.jpg', 'height': 281, 'id': 32, 'width': 500}]

# %%
train_keys[ANNOTATIONS][:2]
# Out:
# [{'area': 34104,
#   'bbox': [155, 96, 196, 174],
#   'category_id': 7,
#   'id': 1,
#   'ignore': 0,
#   'image_id': 12,
#   'iscrowd': 0,
#   'segmentation': [[155, 96, 155, 270, 351, 270, 351, 96]]},
#  {'area': 13110,
#   'bbox': [184, 61, 95, 138],
#   'category_id': 15,
#   'id': 2,
#   'ignore': 0,
#   'image_id': 17,
#   'iscrowd': 0,
#   'segmentation': [[184, 61, 184, 199, 279, 199, 279, 61]]}]

# %%
train_keys[CATEGORIES][:3]
# Out:
# [{'id': 1, 'name': 'aeroplane', 'supercategory': 'none'},
#  {'id': 2, 'name': 'bicycle', 'supercategory': 'none'},
#  {'id': 3, 'name': 'bird', 'supercategory': 'none'}]

# %%
# img = plt.imread(PATH/'VOCdevkit/Images')%
# %ls '{PATH}'/VOCdevkit/VOC2007/JPEGImages

jpegs = list( (PATH/'VOCdevkit/VOC2007/JPEGImages').iterdir());jpegs[:4]
# Out:
# [PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/005866.jpg'),
#  PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/007013.jpg'),
#  PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/000080.jpg'),
#  PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/003315.jpg')]

# %%
img = plt.imread(np.random.choice(jpegs))
plt.imshow(img)

# %%
fig, ax = plt.subplots(figsize=None)
ax.imshow(img)

# %%
train_keys[ANNOTATIONS][:2]
# Out:
# [{'area': 34104,
#   'bbox': [155, 96, 196, 174],
#   'category_id': 7,
#   'id': 1,
#   'ignore': 0,
#   'image_id': 12,
#   'iscrowd': 0,
#   'segmentation': [[155, 96, 155, 270, 351, 270, 351, 96]]},
#  {'area': 13110,
#   'bbox': [184, 61, 95, 138],
#   'category_id': 15,
#   'id': 2,
#   'ignore': 0,
#   'image_id': 17,
#   'iscrowd': 0,
#   'segmentation': [[184, 61, 184, 199, 279, 199, 279, 61]]}]

# %% [markdown]
# # 1.  DATA LOADER

# %%
md = ImageClassifierData.from_csv??

# %%
train_annotations = collections.defaultdict(lambda:[])

# %%
train_annotations = collections.defaultdict(lambda:[])
for o in train_keys[ANNOTATIONS]: 
    if not o['ignore']:
        image_id = o['image_id']
        train_annotations[image_id].append((o['bbox'],o['category_id']))
        
# train_keys[ANNOTATIONS][:1]

# %%
train_annotations[12]
# Out:
# [([155, 96, 196, 174], 7)]

# %%
df = pd.DataFrame

# %%
df = pd.DataFrame(data=train_annotations)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-164dea191dca> in <module>()
# ----> 1 df = pd.DataFrame(data=train_annotations)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# /opt/conda/envs/fastai/lib/python3.6/site-packages/pandas/core/frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length

# %%
df.head()
# Out:
#     file_name  height  id  width
# 0  000012.jpg     333  12    500
# 1  000017.jpg     364  17    480
# 2  000023.jpg     500  23    334
# 3  000026.jpg     333  26    500
# 4  000032.jpg     281  32    500

# %%
images_folder = PATH/'VOCdevkit/VOC2007/JPEGImages'

# %%
md = ImageClassifierData.from_csv(PATH, images_folder, )
