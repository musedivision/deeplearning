# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from fastai.conv_learner import *
from fastai.dataset import *

from pathlib import Path
import json
from PIL import ImageDraw, ImageFont
from matplotlib import patches, patheffects

# %%
PATH = Path('data/pascal/')
list(PATH.iterdir())
# Out:
# [PosixPath('data/pascal/VOCdevkit'),
#  PosixPath('data/pascal/pascal_train2012.json'),
#  PosixPath('data/pascal/pascal_val2012.json'),
#  PosixPath('data/pascal/pascal_val2007.json'),
#  PosixPath('data/pascal/pascal_train2007.json'),
#  PosixPath('data/pascal/pascal_test2007.json')]

# %%
train_keys = json.load((PATH/'pascal_train2007.json').open())
train_keys.keys()
# Out:
# dict_keys(['images', 'type', 'annotations', 'categories'])

# %%
IMAGES, ANNOTATIONS, CATEGORIES = ['images', 'annotations', 'categories']
train_keys[IMAGES][:5]
# Out:
# [{'file_name': '000012.jpg', 'height': 333, 'id': 12, 'width': 500},
#  {'file_name': '000017.jpg', 'height': 364, 'id': 17, 'width': 480},
#  {'file_name': '000023.jpg', 'height': 500, 'id': 23, 'width': 334},
#  {'file_name': '000026.jpg', 'height': 333, 'id': 26, 'width': 500},
#  {'file_name': '000032.jpg', 'height': 281, 'id': 32, 'width': 500}]

# %%
train_keys[ANNOTATIONS][:2]
# Out:
# [{'area': 34104,
#   'bbox': [155, 96, 196, 174],
#   'category_id': 7,
#   'id': 1,
#   'ignore': 0,
#   'image_id': 12,
#   'iscrowd': 0,
#   'segmentation': [[155, 96, 155, 270, 351, 270, 351, 96]]},
#  {'area': 13110,
#   'bbox': [184, 61, 95, 138],
#   'category_id': 15,
#   'id': 2,
#   'ignore': 0,
#   'image_id': 17,
#   'iscrowd': 0,
#   'segmentation': [[184, 61, 184, 199, 279, 199, 279, 61]]}]

# %%
train_keys[CATEGORIES][:3]
# Out:
# [{'id': 1, 'name': 'aeroplane', 'supercategory': 'none'},
#  {'id': 2, 'name': 'bicycle', 'supercategory': 'none'},
#  {'id': 3, 'name': 'bird', 'supercategory': 'none'}]

# %%
# img = plt.imread(PATH/'VOCdevkit/Images')%
# %ls '{PATH}'/VOCdevkit/VOC2007/JPEGImages


jpegs = list( (PATH/'VOCdevkit/VOC2007/JPEGImages').iterdir());jpegs[:4]
# Out:
# [PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/005866.jpg'),
#  PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/007013.jpg'),
#  PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/000080.jpg'),
#  PosixPath('data/pascal/VOCdevkit/VOC2007/JPEGImages/003315.jpg')]

# %%
img = plt.imread(np.random.choice(jpegs))
plt.imshow(img)

# %%
fig, ax = plt.subplots(figsize=None)
ax.imshow(img)
ax.draw??

# %% [markdown]
# ## jeremys awesome functions

# %%
draw_idx(17)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-42-ee4a8da10bdd> in <module>()
# ----> 1 draw_idx(17)
#
# <ipython-input-41-2df94c795c93> in draw_idx(i)
#       1 def draw_idx(i):
# ----> 2     im_a = trn_anno[i]
#       3     im = open_image(IMG_PATH/trn_fns[i])
#       4     print(im.shape)
#       5     draw_im(im, im_a)
#
# NameError: name 'trn_anno' is not defined

# %%
train_keys[ANNOTATIONS][:1]
# Out:
# [{'area': 34104,
#   'bbox': [155, 96, 196, 174],
#   'category_id': 7,
#   'id': 1,
#   'ignore': 0,
#   'image_id': 12,
#   'iscrowd': 0,
#   'segmentation': [[155, 96, 155, 270, 351, 270, 351, 96]]}]

# %% [markdown]
# # 1.  DATA LOADER

# %%
md = ImageClassifierData.from_csv??

# %%
md = ImageClassifierData.from_csv

# %%
train_annotations = collections.defaultdict(lambda:[])

# %%
train_annotations = collections.defaultdict(lambda:[])
for o in train_keys[ANNOTATIONS]: 
    if not o['ignore']:
        image_id = o['image_id']
        bb = o['bbox']
        bb = np.array([bb[1], bb[0], bb[3]+bb[1]-1, bb[2]+bb[0]-1])
        train_annotations[image_id].append((bb,o['category_id']))
        
# train_keys[ANNOTATIONS][:1]

# %%
train_annotations[12]
# Out:
# [(array([ 96, 155, 269, 350]), 7)]

# %%
def get_largest(b):
    if not b: raise Exception()
    b = sorted(b, key=lambda x: np.product(x[0][-2:]-x[0][:2]), reverse=True)
    return b[0]

# %%
largest_items = {a: get_largest(b) for a,b in train_annotations.items() }

# %%
train_filenames = [o['file_name'] for o in train_keys[IMAGES]]; train_filenames[:1]
# Out:
# ['000012.jpg']

# %%
IMG_PATH = PATH/'VOCdevkit/VOC2007/JPEGImages'

# %%
def draw_outline(o, lw):
    o.set_path_effects([patheffects.Stroke(
        linewidth=lw, foreground='black'), patheffects.Normal()])
    
def draw_rect(ax, b):
    patch = ax.add_patch(patches.Rectangle(b[:2], *b[-2:], fill=False, edgecolor='white', lw=2))
    draw_outline(patch, 4)
    
def draw_text(ax, xy, txt, sz=14):
    text = ax.text(*xy, txt,
        verticalalignment='top', color='white', fontsize=sz, weight='bold')
    draw_outline(text, 1)
    
def draw_im(im, ann):
    ax = show_img(im, figsize=(16,8))
    for b,c in ann:
        b = bb_hw(b)
        draw_rect(ax, b)
        draw_text(ax, b[:2], cats[c], sz=16)

def draw_idx(i):
    im_a = train_annotations[i]
    im = open_image(IMG_PATH/train_filenames[i])
    print(im.shape)
    draw_im(im, im_a)

# %%
draw_idx(1)
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-60-5586e03c2c45> in <module>()
# ----> 1 draw_idx(1)
#
# <ipython-input-57-e69a6cd73731> in draw_idx(i)
#      21 def draw_idx(i):
#      22     im_a = train_annotations[i]
# ---> 23     im = open_image(IMG_PATH/train_filenames[i])
#      24     print(im.shape)
#      25     draw_im(im, im_a)
#
# /notebooks/volume/fastai/dataset.py in open_image(fn)
#     197     flags = cv2.IMREAD_UNCHANGED+cv2.IMREAD_ANYDEPTH+cv2.IMREAD_ANYCOLOR
#     198     if not os.path.exists(fn):
# --> 199         raise OSError('No such file or directory: {}'.format(fn))
#     200     elif os.path.isdir(fn):
#     201         raise OSError('Is a directory: {}'.format(fn))
#
# OSError: No such file or directory: data/pascal/VOCdevkit/VOC2007/JPEGImages/000017.jpg

# %%
df = pd.DataFrame({'fn': [train_keys[IMAGES]: for o in ], 'cats': []}, columns=['fn', 'cats'])
# Out:
#   File "<ipython-input-1-fb51450cf5b3>", line 1
#     df = pd.DataFrame({'fn': [train_keys[IMAGES]: ], 'cats': []}, columns=['fn', 'cats'])
#                                                 ^
# SyntaxError: invalid syntax

# %%
df.head()
# Out:
#     file_name  height  id  width
# 0  000012.jpg     333  12    500
# 1  000017.jpg     364  17    480
# 2  000023.jpg     500  23    334
# 3  000026.jpg     333  26    500
# 4  000032.jpg     281  32    500

# %%
images_folder = PATH/'VOCdevkit/VOC2007/JPEGImages'

# %%
md = ImageClassifierData.from_csv(PATH, images_folder, )
